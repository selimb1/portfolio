# %% [markdown]
# # La brecha entre saber y hacer
#
# **Decisión:** ¿Qué fricción conductual debería orientar una intervención financiera?
#
# Notebook ejecutado sobre la muestra versionada del repositorio.

# %% [markdown]
# ## 1. Contrato y calidad
#
# Se comprueba la trazabilidad de la fuente, el tamaño de la muestra y las métricas finitas.

# %%
from pathlib import Path
from IPython.display import Image, display
from portfolio_analytics.common import project_root, read_json
root = project_root()
project = root / 'projects/03-behavioral-finance'
source = read_json(project / 'data/source.json')
display({'rows': source['rows'], 'source': source['url'], 'retrieved_at': source['retrieved_at']})
# Out:
# {'rows': 6394,
#  'source': 'https://www.consumerfinance.gov/documents/5614/NFWBS_PUF_2016_data.csv',
#  'retrieved_at': '2026-07-30T05:05:06+00:00'}

# %% [markdown]
# ## 2. Ejecución reproducible
#
# La siguiente celda vuelve a correr la lógica compartida por el script y las pruebas.

# %%
from portfolio_analytics.behavioral_finance import analyze
metrics = analyze(project / 'data/sample.csv', project / 'outputs')
display(metrics)
# Out:
# {'respondents': 6394,
#  'clustered_respondents': 6255,
#  'segments': 4,
#  'cluster_stability_ari': 0.945,
#  'highest_wellbeing_segment': 'Resilientes planificadores',
#  'lowest_wellbeing_segment': 'Vulnerables reactivos',
#  'wellbeing_gap_points': 29.6,
#  'strongest_association': 'ABSORBSHOCK',
#  'weighted_regression_r2': 0.509}

# %% [markdown]
# ## 3. Resultado visual
#
# La figura se genera desde los mismos datos y queda versionada para revisión rápida.

# %%
display(Image(filename=str(project / 'outputs/figure.png'), width=900))

# %% [markdown]
# ## 4. Conclusión y límite
#
# Los perfiles requieren acciones distintas; la asociación observada no demuestra causalidad.
